# %%
import pandas as pd
import numpy as np

# %%
reviwedata_set=pd.read_csv(r"F:\project.py\data set predection\Sentiment Analysis\Reviews.csv")
reviwedata_set
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
reviwedata_set.shape
# Out:
# (568454, 10)

# %%
reviwedata_set.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %%
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
reviwedata_set
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
from nltk.corpus import stopwords
import nltk

# Step 2: Download Stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Step 3: Load Dataset
df = pd.read_csv(r"F:\project.py\data set predection\Sentiment Analysis\Reviews.csv")  # ✅ Change path as needed

# Step 4: Preprocess Text (Using re instead of nltk)
def clean_text(text):
    tokens = re.findall(r'\b\w+\b', str(text).lower())  # Tokenize using regex
    words = [word for word in tokens if word not in stop_words]
    return ' '.join(words)

df['Clean_Review'] = df['Text'].apply(clean_text)

# Step 5: Create Sentiment Labels from Score
def label_sentiment(score):
    if score >= 4:
        return 1  # Positive
    elif score == 3:
        return 0  # Neutral
    else:
        return -1  # Negative

df['Label'] = df['Score'].apply(label_sentiment)

# Step 6: Split Data
X_train, X_test, y_train, y_test = train_test_split(
    df['Clean_Review'], df['Label'], test_size=0.3, random_state=42
)

# Step 7: TF-IDF Vectorization
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Step 8: Train the Naive Bayes Model
model = MultinomialNB()
model.fit(X_train_vec, y_train)

# Step 9: Evaluate Model
y_pred = model.predict(X_test_vec)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Step 10: Predict a Custom Review
def predict_sentiment(review):
    cleaned = clean_text(review)
    vectorized = vectorizer.transform([cleaned])
    pred = model.predict(vectorized)[0]
    sentiment_map = {1: "Positive", 0: "Neutral", -1: "Negative"}
    return sentiment_map[pred]

# Example Prediction
custom_review = "food is bade"

print("\nCustom Review Sentiment:", predict_sentiment(custom_review))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gokul\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Accuracy: 0.8028932137893829
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           -1       0.91      0.15      0.26     24278
#            0       0.22      0.00      0.00     12850
#            1       0.80      1.00      0.89    133409
#
#     accuracy                           0.80    170537
#    macro avg       0.64      0.38      0.38    170537
# weighted avg       0.77      0.80      0.73    170537
#
#
# Custom Review Sentiment: Positive
